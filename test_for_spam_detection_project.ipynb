# %%
! pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /home/harsh/miniconda3/lib/python3.12/site-packages (1.40.1)
# Requirement already satisfied: altair<6,>=4.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (5.4.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (18.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (13.9.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/harsh/miniconda3/lib/python3.12/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in /home/harsh/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.5.2 in /home/harsh/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (1.13.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/harsh/miniconda3/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/harsh/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/harsh/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/harsh/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/harsh/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/harsh/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/harsh/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/harsh/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/harsh/miniconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/harsh/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/harsh/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/harsh/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/harsh/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/harsh/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/harsh/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import streamlit as  st
import warnings

# Filter out warnings
warnings.filterwarnings("ignore", category=UserWarning)

# Load data
data = pd.read_csv("/home/harsh/PROJECTS/CREDIT CARD FRAUD DETECTION/creditcard.csv")

# Separate legitimate and fraudulent transactions
legit = data[data.Class == 0]
fraud = data[data.Class == 1]

# Undersample legitimate transactions to balance the classes
legit_sample = legit.sample(n=len(fraud), random_state=2)
data = pd.concat([legit_sample, fraud], axis=0)

# Split data into training and testing sets
X = data.drop(columns="Class", axis=1)
y = data["Class"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=2)

# Train logistic regression model
model = LogisticRegression(max_iter=1000, solver='liblinear')
model.fit(X_train, y_train)

# Evaluate model performance
train_acc = accuracy_score(model.predict(X_train), y_train)
test_acc = accuracy_score(model.predict(X_test), y_test)

# Create Streamlit app
st.title("Credit Card Fraud Detection Model")
st.write(f"Model Training Accuracy: {train_acc:.2f}")
st.write(f"Model Testing Accuracy: {test_acc:.2f}")

st.write("Enter the following features to check if the transaction is legitimate or fraudulent:")

# Create input fields for user to enter feature values
input_df = st.text_input('Input All features (comma-separated values for each feature)')

# Create a button to submit input and get prediction
submit = st.button("Submit")

if submit:
    if input_df:
        # Get input feature values
        input_df_lst = input_df.split(',')
        
        # Validate that the number of features matches the model's expectation
        if len(input_df_lst) != X_train.shape[1]:
            st.write(f"Error: Please enter exactly {X_train.shape[1]} features.")
        else:
            try:
                # Convert the input values to float and reshape for prediction
                features = np.array(input_df_lst, dtype=np.float64).reshape(1, -1)
                
                # Make prediction
                prediction = model.predict(features)
                
                # Display result
                if prediction[0] == 0:
                    st.write("Legitimate transaction")
                else:
                    st.write("Fraudulent transaction")
            except ValueError:
                st.write("Error: Please enter numeric values for all features.")
    else:
        st.write("Please enter the feature values.")
# Out:
# 2025-02-04 16:17:15.306 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.432
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/harsh/miniconda3/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-02-04 16:17:15.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.443 Session state does not function when running a script without `streamlit run`
# 2025-02-04 16:17:15.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 16:17:15.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
